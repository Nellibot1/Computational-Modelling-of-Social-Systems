# %% [markdown]
# # Assignment 2: Reproducing figures from OASIS Open Agent Social Interaction Simulations with One Million Agents Paper
#
# For the second assignment our task is to replicate Figure 4 to 6 with the results of 10 Agents based on the OASIS Paper.
# The phenomen studied in the paper is Agent based model simulations on real scenarios: Twitter/Reddit with LLMs to understand how to use agent based models on real scenarios of social media platforms.
#
# The paper is by Yang et al., 2024.
# https://arxiv.org/abs/2411.11581
# https://doi.org/10.48550/arXiv.2411.11581
#
# Furthermore did we work with the reddit dataset of the github server of Yang et al., 2024. We reproduced the social phenomenas of polarization and herd effect in a simplified manner on a small scale using mesa simulation modelling. Used mesa model is 3.3.1.
#
# https://github.com/camel-ai/oasis.

# %% [markdown]
# <img src ='OASIS.png'>

# %% [markdown]
# ## Workflow and internal mechanisms of OASIS
#
# OASIS is a LLM based simulator for various social media applications. It is built upon the structure of traditional social media platforms and consists of 5 key components: Environment Server, RecSy, Agent Module, Time Engine and Scalable Inferencer (Yang et al., 2024). The phases in which the model functions is split into regristration phase and simulation phase.
#
# ### Regristration Phase
# During this phase OASIS registers each user (agent),with user information, including name, self description and historical posts furthermore does the agent receives a character and action description so actions align with it.
#
# ### Simulation Phase
# In the Simulation Phase the enviroments sends user related information like past behaviour and self description to the Recommender System which then filters post from the environment and suggests post that are likely to be interesting to the agent. Based on the posts and description the agent takes actions like e.g. reposting. Chain_of_thought reasoning helps in understanding the models behaviour.
#
# ### Environment Server
# The environment server maintains the status and data of the platforms such as user info, user relationsships,posts, comments,recommendations and other action related traces which are stored in different tables. The recommendation table is populated by outputs from the Recommender System after the analysis of the users trace table.
#
# ### RecSys
# The recommender system controls the information seen by agent which is aligned with either X or the Reddit recommender system. The sources of post come from the in network, the agents followed directly by the user and the out of network, post from the broader 'world' simulation. In network content is recommended ranked by popularity of e.g. likes and the out of network posts are being recommended based on the interest matches of the agent measured by interest vectors similarity. Factors such as priorising recent post and number of followers of the posting user are also taken into consideration (influencer).
# --> Depending on which Social Media we use we can add information about the algorithm of recsystem
#
# ### Agent Module
# The agent module is based on LLM with corefeatures of agent module inherited from CAMEL (Li et al., 2023).The agent module consists of memory modula and action module. The memory stores the information encountered to help the agent understand its role when performing actions. The action module enables different types of interactions such as, sign up, refresh,searching users/posts, create, repost follow and many more associated functions of traditional social media plattforms. CoT reasoning is used for the better interpretability of the agents behaviour.
#
# ### Time Engine
# Time engine incorperates temporal features that reflect the real world online behaviour patterns, such as hourly activity level based on historical interactions. Each agent has a 24 dimensional vector that represents the probability of activity in each hour which then activates the user based on the probabilities.
#
# ### Scalable Inference
# The design of the distribution system is highly scalabale. The agents, environments and inference server operate independently and exchange data through information communication channels. This allos the agents to send multiple requests at the same time while waiting for resposnes of previous interactions, simulating real world behaviour.
#
# ### Large Scale User Generation
# The user generation algorithms combines real user data with a relationship network, which enables to simulation of up to 1 million users which still having a scale-free network. The algorithm generates diverse user profiles based on population distributions with interest based sampling of core and ordinary users with a probability of 0.2.
#
#
# For our Model we have created a simplified Version with Mesa Agent based modelling.

# %% [markdown]
# <img src ='Workflow.png'>

# %% [markdown]
# ## Experiment 1
# The paper showcases how interaction with the same opinion might cause a polarization within the community and the users. We are trying to reproduce this behvaiour on a small scale with 10 agents to showcase this. All agents start with a different starting position on a shared discussion topic after repeated interaction with posts some agents move towards more polarized opinion. We compare the opinions at different starting points to the beginning round 0.

# %%
# %pip install mesa[rec]
# %pip install seaborn
# %pip install camel-oasis
# Out:
# zsh:1: no matches found: mesa[rec]
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping /opt/anaconda3/lib/python3.11/site-packages/pydantic_core-2.14.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/anaconda3/lib/python3.11/site-packages/pydantic_core-2.14.6.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: seaborn in /opt/anaconda3/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /opt/anaconda3/lib/python3.11/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=0.25 in /opt/anaconda3/lib/python3.11/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /opt/anaconda3/lib/python3.11/site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# WARNING: Skipping /opt/anaconda3/lib/python3.11/site-packages/pydantic_core-2.14.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/anaconda3/lib/python3.11/site-packages/pydantic_core-2.14.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/anaconda3/lib/python3.11/site-packages/pydantic_core-2.14.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/anaconda3/lib/python3.11/site-packages/pydantic_core-2.14.6.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping /opt/anaconda3/lib/python3.11/site-packages/pydantic_core-2.14.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/anaconda3/lib/python3.11/site-packages/pydantic_core-2.14.6.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: camel-oasis in /opt/anaconda3/lib/python3.11/site-packages (0.2.5)
# Requirement already satisfied: cairocffi==1.7.1 in /opt/anaconda3/lib/python3.11/site-packages (from camel-oasis) (1.7.1)
# Requirement already satisfied: camel-ai==0.2.78 in /opt/anaconda3/lib/python3.11/site-packages (from camel-oasis) (0.2.78)
# Requirement already satisfied: igraph==0.11.6 in /opt/anaconda3/lib/python3.11/site-packages (from camel-oasis) (0.11.6)
# Requirement already satisfied: neo4j==5.23.0 in /opt/anaconda3/lib/python3.11/site-packages (from camel-oasis) (5.23.0)
# Requirement already satisfied: openapi-spec-validator==0.7.1 in /opt/anaconda3/lib/python3.11/site-packages (from camel-oasis) (0.7.1)
# Requirement already satisfied: pandas==2.2.2 in /opt/anaconda3/lib/python3.11/site-packages (from camel-oasis) (2.2.2)
# Requirement already satisfied: pillow==10.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from camel-oasis) (10.3.0)
# Requirement already satisfied: prance==23.6.21.0 in /opt/anaconda3/lib/python3.11/site-packages (from camel-oasis) (23.6.21.0)
# Requirement already satisfied: pre-commit==3.7.1 in /opt/anaconda3/lib/python3.11/site-packages (from camel-oasis) (3.7.1)
# Requirement already satisfied: pytest==8.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from camel-oasis) (8.2.0)
# Requirement already satisfied: pytest-asyncio==0.23.6 in /opt/anaconda3/lib/python3.11/site-packages (from camel-oasis) (0.23.6)
# Requirement already satisfied: requests_oauthlib==2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from camel-oasis) (2.0.0)
# Requirement already satisfied: sentence-transformers==3.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from camel-oasis) (3.0.0)
# Requirement already satisfied: slack_sdk==3.31.0 in /opt/anaconda3/lib/python3.11/site-packages (from camel-oasis) (3.31.0)
# Requirement already satisfied: unstructured==0.13.7 in /opt/anaconda3/lib/python3.11/site-packages (from camel-oasis) (0.13.7)
# Requirement already satisfied: cffi>=1.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from cairocffi==1.7.1->camel-oasis) (1.16.0)
# Requirement already satisfied: astor>=0.8.1 in /opt/anaconda3/lib/python3.11/site-packages (from camel-ai==0.2.78->camel-oasis) (0.8.1)
# Requirement already satisfied: colorama<0.5,>=0.4.6 in /opt/anaconda3/lib/python3.11/site-packages (from camel-ai==0.2.78->camel-oasis) (0.4.6)
# Requirement already satisfied: docstring-parser<0.18,>=0.17.0 in /opt/anaconda3/lib/python3.11/site-packages (from camel-ai==0.2.78->camel-oasis) (0.17.0)
# Requirement already satisfied: httpx<1.0.0dev,>=0.28.0 in /opt/anaconda3/lib/python3.11/site-packages (from camel-ai==0.2.78->camel-oasis) (0.28.1)
# Requirement already satisfied: jsonschema<5,>=4 in /opt/anaconda3/lib/python3.11/site-packages (from camel-ai==0.2.78->camel-oasis) (4.26.0)
# Requirement already satisfied: mcp>=1.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from camel-ai==0.2.78->camel-oasis) (1.27.0)
# Requirement already satisfied: openai<2,>=1.86.0 in /opt/anaconda3/lib/python3.11/site-packages (from camel-ai==0.2.78->camel-oasis) (1.109.1)
# Requirement already satisfied: psutil<6,>=5.9.8 in /opt/anaconda3/lib/python3.11/site-packages (from camel-ai==0.2.78->camel-oasis) (5.9.8)
# Requirement already satisfied: pydantic>=2.10.6 in /opt/anaconda3/lib/python3.11/site-packages (from camel-ai==0.2.78->camel-oasis) (2.13.2)
# Requirement already satisfied: tiktoken<0.8,>=0.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from camel-ai==0.2.78->camel-oasis) (0.7.0)
# Requirement already satisfied: websockets<15.1,>=13.0 in /opt/anaconda3/lib/python3.11/site-packages (from camel-ai==0.2.78->camel-oasis) (15.0.1)
# Requirement already satisfied: texttable>=1.6.2 in /opt/anaconda3/lib/python3.11/site-packages (from igraph==0.11.6->camel-oasis) (1.7.0)
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.11/site-packages (from neo4j==5.23.0->camel-oasis) (2023.3.post1)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from openapi-spec-validator==0.7.1->camel-oasis) (0.3.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in /opt/anaconda3/lib/python3.11/site-packages (from openapi-spec-validator==0.7.1->camel-oasis) (1.12.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from openapi-spec-validator==0.7.1->camel-oasis) (0.6.3)
# Requirement already satisfied: numpy>=1.23.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas==2.2.2->camel-oasis) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas==2.2.2->camel-oasis) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.11/site-packages (from pandas==2.2.2->camel-oasis) (2023.3)
# Requirement already satisfied: chardet>=3.0 in /opt/anaconda3/lib/python3.11/site-packages (from prance==23.6.21.0->camel-oasis) (4.0.0)
# Requirement already satisfied: ruamel.yaml>=0.17.10 in /opt/anaconda3/lib/python3.11/site-packages (from prance==23.6.21.0->camel-oasis) (0.17.21)
# Requirement already satisfied: requests>=2.25 in /opt/anaconda3/lib/python3.11/site-packages (from prance==23.6.21.0->camel-oasis) (2.32.5)
# Requirement already satisfied: six~=1.15 in /opt/anaconda3/lib/python3.11/site-packages (from prance==23.6.21.0->camel-oasis) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/lib/python3.11/site-packages (from prance==23.6.21.0->camel-oasis) (23.1)
# Requirement already satisfied: cfgv>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from pre-commit==3.7.1->camel-oasis) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from pre-commit==3.7.1->camel-oasis) (2.6.19)
# Requirement already satisfied: nodeenv>=0.11.1 in /opt/anaconda3/lib/python3.11/site-packages (from pre-commit==3.7.1->camel-oasis) (1.10.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.11/site-packages (from pre-commit==3.7.1->camel-oasis) (6.0.1)
# Requirement already satisfied: virtualenv>=20.10.0 in /opt/anaconda3/lib/python3.11/site-packages (from pre-commit==3.7.1->camel-oasis) (21.2.4)
# Requirement already satisfied: iniconfig in /opt/anaconda3/lib/python3.11/site-packages (from pytest==8.2.0->camel-oasis) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from pytest==8.2.0->camel-oasis) (1.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from requests_oauthlib==2.0.0->camel-oasis) (3.3.1)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /opt/anaconda3/lib/python3.11/site-packages (from sentence-transformers==3.0.0->camel-oasis) (4.41.2)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.11/site-packages (from sentence-transformers==3.0.0->camel-oasis) (4.65.0)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from sentence-transformers==3.0.0->camel-oasis) (2.3.1)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.11/site-packages (from sentence-transformers==3.0.0->camel-oasis) (1.2.2)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.11/site-packages (from sentence-transformers==3.0.0->camel-oasis) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /opt/anaconda3/lib/python3.11/site-packages (from sentence-transformers==3.0.0->camel-oasis) (0.23.2)
# Requirement already satisfied: filetype in /opt/anaconda3/lib/python3.11/site-packages (from unstructured==0.13.7->camel-oasis) (1.2.0)
# Requirement already satisfied: python-magic in /opt/anaconda3/lib/python3.11/site-packages (from unstructured==0.13.7->camel-oasis) (0.4.27)
# Requirement already satisfied: lxml in /opt/anaconda3/lib/python3.11/site-packages (from unstructured==0.13.7->camel-oasis) (5.1.1)
# Requirement already satisfied: nltk in /opt/anaconda3/lib/python3.11/site-packages (from unstructured==0.13.7->camel-oasis) (3.8.1)
# Requirement already satisfied: tabulate in /opt/anaconda3/lib/python3.11/site-packages (from unstructured==0.13.7->camel-oasis) (0.9.0)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.11/site-packages (from unstructured==0.13.7->camel-oasis) (4.12.2)
# Requirement already satisfied: emoji in /opt/anaconda3/lib/python3.11/site-packages (from unstructured==0.13.7->camel-oasis) (2.15.0)
# Requirement already satisfied: dataclasses-json in /opt/anaconda3/lib/python3.11/site-packages (from unstructured==0.13.7->camel-oasis) (0.6.7)
# Requirement already satisfied: python-iso639 in /opt/anaconda3/lib/python3.11/site-packages (from unstructured==0.13.7->camel-oasis) (2026.1.31)
# Requirement already satisfied: langdetect in /opt/anaconda3/lib/python3.11/site-packages (from unstructured==0.13.7->camel-oasis) (1.0.9)
# Requirement already satisfied: rapidfuzz in /opt/anaconda3/lib/python3.11/site-packages (from unstructured==0.13.7->camel-oasis) (3.14.5)
# Requirement already satisfied: backoff in /opt/anaconda3/lib/python3.11/site-packages (from unstructured==0.13.7->camel-oasis) (2.2.1)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.11/site-packages (from unstructured==0.13.7->camel-oasis) (4.15.0)
# Requirement already satisfied: unstructured-client in /opt/anaconda3/lib/python3.11/site-packages (from unstructured==0.13.7->camel-oasis) (0.43.2)
# Requirement already satisfied: wrapt in /opt/anaconda3/lib/python3.11/site-packages (from unstructured==0.13.7->camel-oasis) (1.14.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.11/site-packages (from cffi>=1.1.0->cairocffi==1.7.1->camel-oasis) (2.21)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1.0.0dev,>=0.28.0->camel-ai==0.2.78->camel-oasis) (4.13.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1.0.0dev,>=0.28.0->camel-ai==0.2.78->camel-oasis) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1.0.0dev,>=0.28.0->camel-ai==0.2.78->camel-oasis) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1.0.0dev,>=0.28.0->camel-ai==0.2.78->camel-oasis) (3.4)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0dev,>=0.28.0->camel-ai==0.2.78->camel-oasis) (0.16.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.0->camel-oasis) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.0->camel-oasis) (2023.10.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema<5,>=4->camel-ai==0.2.78->camel-oasis) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema<5,>=4->camel-ai==0.2.78->camel-oasis) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema<5,>=4->camel-ai==0.2.78->camel-oasis) (0.30.2)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema<5,>=4->camel-ai==0.2.78->camel-oasis) (0.30.0)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi-spec-validator==0.7.1->camel-oasis) (0.4.4)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/anaconda3/lib/python3.11/site-packages (from mcp>=1.3.0->camel-ai==0.2.78->camel-oasis) (0.4.3)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/anaconda3/lib/python3.11/site-packages (from mcp>=1.3.0->camel-ai==0.2.78->camel-oasis) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in /opt/anaconda3/lib/python3.11/site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.3.0->camel-ai==0.2.78->camel-oasis) (2.12.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/anaconda3/lib/python3.11/site-packages (from mcp>=1.3.0->camel-ai==0.2.78->camel-oasis) (0.0.9)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/anaconda3/lib/python3.11/site-packages (from mcp>=1.3.0->camel-ai==0.2.78->camel-oasis) (3.3.4)
# Requirement already satisfied: starlette>=0.27 in /opt/anaconda3/lib/python3.11/site-packages (from mcp>=1.3.0->camel-ai==0.2.78->camel-oasis) (1.0.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /opt/anaconda3/lib/python3.11/site-packages (from mcp>=1.3.0->camel-ai==0.2.78->camel-oasis) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /opt/anaconda3/lib/python3.11/site-packages (from mcp>=1.3.0->camel-ai==0.2.78->camel-oasis) (0.44.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai<2,>=1.86.0->camel-ai==0.2.78->camel-oasis) (1.8.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai<2,>=1.86.0->camel-ai==0.2.78->camel-oasis) (0.14.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.11/site-packages (from openai<2,>=1.86.0->camel-ai==0.2.78->camel-oasis) (1.3.0)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/lib/python3.11/site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi-spec-validator==0.7.1->camel-oasis) (0.1.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic>=2.10.6->camel-ai==0.2.78->camel-oasis) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.2 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic>=2.10.6->camel-ai==0.2.78->camel-oasis) (2.46.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.25->prance==23.6.21.0->camel-oasis) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.25->prance==23.6.21.0->camel-oasis) (2.0.7)
# Requirement already satisfied: regex>=2022.1.18 in /opt/anaconda3/lib/python3.11/site-packages (from tiktoken<0.8,>=0.7.0->camel-ai==0.2.78->camel-oasis) (2023.10.3)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==3.0.0->camel-oasis) (1.12)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==3.0.0->camel-oasis) (3.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==3.0.0->camel-oasis) (3.1.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers==3.0.0->camel-oasis) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers==3.0.0->camel-oasis) (0.4.3)
# Requirement already satisfied: distlib<1,>=0.3.7 in /opt/anaconda3/lib/python3.11/site-packages (from virtualenv>=20.10.0->pre-commit==3.7.1->camel-oasis) (0.4.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /opt/anaconda3/lib/python3.11/site-packages (from virtualenv>=20.10.0->pre-commit==3.7.1->camel-oasis) (4.9.6)
# Requirement already satisfied: python-discovery>=1.2.2 in /opt/anaconda3/lib/python3.11/site-packages (from virtualenv>=20.10.0->pre-commit==3.7.1->camel-oasis) (1.2.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->unstructured==0.13.7->camel-oasis) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/lib/python3.11/site-packages (from dataclasses-json->unstructured==0.13.7->camel-oasis) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from dataclasses-json->unstructured==0.13.7->camel-oasis) (0.9.0)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.11/site-packages (from nltk->unstructured==0.13.7->camel-oasis) (8.3.1)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.11/site-packages (from nltk->unstructured==0.13.7->camel-oasis) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn->sentence-transformers==3.0.0->camel-oasis) (2.2.0)
# Requirement already satisfied: aiofiles>=25.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from unstructured-client->unstructured==0.13.7->camel-oasis) (25.1.0)
# Requirement already satisfied: pypdf>=6.9.2 in /opt/anaconda3/lib/python3.11/site-packages (from unstructured-client->unstructured==0.13.7->camel-oasis) (6.10.2)
# Requirement already satisfied: pypdfium2>=5.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from unstructured-client->unstructured==0.13.7->camel-oasis) (5.7.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from unstructured-client->unstructured==0.13.7->camel-oasis) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic-settings>=2.5.2->mcp>=1.3.0->camel-ai==0.2.78->camel-oasis) (0.21.0)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.3.0->camel-ai==0.2.78->camel-oasis) (42.0.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured==0.13.7->camel-oasis) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers==3.0.0->camel-oasis) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence-transformers==3.0.0->camel-oasis) (1.3.0)
# WARNING: Skipping /opt/anaconda3/lib/python3.11/site-packages/pydantic_core-2.14.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/anaconda3/lib/python3.11/site-packages/pydantic_core-2.14.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/anaconda3/lib/python3.11/site-packages/pydantic_core-2.14.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/anaconda3/lib/python3.11/site-packages/pydantic_core-2.14.6.dist-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.

# %%
import mesa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import os 
import sys
import json
import sqlite3
from pathlib import Path 
from IPython.display import JSON, display

# %%
#using the reddit data set from Oasis paper
Datapath = Path("/Users/janniella/Desktop/SoSE26/Computational Modelling/OASIS/data/reddit/user_data_36.json")

with open (Datapath, "r") as file:
    userdata = json.load(file)
len(userdata)

users10 = userdata[:10] #selecting 10 users from the dataset



display(JSON(users10)) #checking whether it opened 10 userdatas correctly
with open ("users10output.json","w") as file:
    json.dump(users10,file,indent=2, ensure_ascii=False)
#creating a json file with the information of the users that will later be used for the probability of the users

# %%
#creating the agents from the users

class Reddit_Useragent(mesa.Agent):
    def __init__(self,model,profile,firstopinion,community,pronetoopinions,confirmationbias,activity):
        super ().__init__(model)

        #data from the oasis model
        self.username = profile["username"]
        self.bio = profile["bio"]
        self.persona = profile["persona"]
        self.age = profile["age"]
        self.gender = profile["gender"]
        self.country = profile["country"]
        self.interested_topics = profile["interested_topics"]
        self.mbti = profile["mbti"]
        self.profession = profile["profession"]

        #properties important for the simulation 
        self.opinion = firstopinion
        self.community = community
        self.pronetoopinions = pronetoopinions #how easily the agent changes opinion
        self.confirmationbias = confirmationbias # how strongly the agent favors agreeing
        self.activity = activity 

    
    # it the post is close to the opinion of the user it moves towards it else it moves away from it if it differs from opinion
    def react_to_post(self,post):
        change = post.stanceofpost - self.opinion
        opiniongap = abs(self.opinion - post.stanceofpost)
        
        if self.opinion * post.stanceofpost >= 0:
            #if similar reinforce
            self.opinion += self.pronetoopinions * (0.15 + self.confirmationbias * 0.1)*change

        else: 
            #if opposite reinforce
            self.opinion -= self.pronetoopinions * (0.10 + self.confirmationbias * 0.1) * change
        self.opinion = float(np.clip(self.opinion,-1,1))
        #if the agent and post have the same direction it gets a upvote else downvote like in reddit
        if self.opinion * post.stanceofpost >= 0:
            post.upvotes +=1
        else:
            post.downvotes += 1

    
    def createpostfromopinion(self):
        
        return{
            "community": self.community, 
            "stanceofpost": self.opinion, 
            "topics": self.interested_topics,
            'treatment': np.random.choice(['up-treated', 'down-treated', 'control']) # added randomly chosen treatment
        }

# %% [markdown]
# ### Simulate the probability of behaviour by looking at persona, topics of interest and MBTI information given my the dataset
#
# The dataset of Oasis gives information such as MBTI and topics of interest as well as vague stance with words such as "passionate", "research". These are used in our model to approximate the probability of a certain behaviour the agent will elicit.
#
#
# The MBTI is also taken into account as the Letters in it gives insight on how likely a person is acting in sensing vs intuition and feeling vs thinking as well as extroversion vs introvertion (that could be useful for herd effect probability).
#
# <img src ='MBTI.png'>
# Example of how common each statistic is.
#
# source: https://crowncounseling.com/statistics/myers-briggs/

# %%
# to create a probability for the probability of suceptability to opinions 
# we use the information given by the persona to vaguely create direction 
# for this we looked at the output given by the 10 agents created and analyzed the keywords in their bio,profession and interested topics
#probabilities are being clipped to 0 and 1 
def clippingprobability (value):
    return min(max(value, 0.0),1.0)


def traitsfrompersona (profile):
    persona = profile["persona"].lower()
    bio = profile ["bio"].lower()
    topics = " ".join(profile["interested_topics"]).lower()
    mbti = profile["mbti"].upper() 

    text = persona + "" + bio + "" + topics

    #baselinevalues
    pronetoopinions = 0.5
    confirmationbias = 0.5
    activity = 0.85
    
    # persona based probability
    #these words suggest that the person is likely to be active and strongminded in their opinion
    if any(word in text for word in [
        "passionate", "enthusiast","advocate","dedicated","driven"
    ]):
           activity += 0.08
           confirmationbias +=0.06

    #these traits suggest that the agent is likely analytical and logical,therefore possibly less suceptible to opinions based on emotions
    if any(word in text for word in [
        "analytical", "analyzing","market trends","logical","methodical","detail-oriented","financial data"
    ]):
           pronetoopinions -= 0.08
           confirmationbias +=0.05

    #these words tend to present a person who is open minded to different opinions
    if any(word in text for word in [
        "curious", "exploring","learning","seeking knowledge","exchange ideas"
    ]):
           pronetoopinions += 0.08

    #tends to present a user who is active in discussions    
    if any(word in text for word in [
        "community","connecting","discussing","sharing insights","exchange ideas","social issues"
    ]):
           activity += 0.08

    # more agreeable kind person 
    if any(word in text for word in [
        "helping others","positive impact","greater good","compassionate","empathetic","social welfare"
    ]):
           pronetoopinions += 0.05
           confirmationbias -= 0.05

    

    # MBTI based probabilities E extroverted, I introverted, N intuition, S sensing, T thinking, F feeling, J judging , P perceiving
    if "E" in mbti: 
        activity += 0.10
    if "I" in mbti: 
        activity -= 0.05

    if "N" in mbti: 
        pronetoopinions += 0.05
    if "S" in mbti: 
        confirmationbias += 0.05

    if "T" in mbti: 
        pronetoopinions -= 0.05
    if "F" in mbti: 
        pronetoopinions += 0.05
    
    if "J" in mbti: 
        confirmationbias += 0.05
    if "P" in mbti: 
        confirmationbias -= 0.05

    return {
        "pronetoopinions": clippingprobability(pronetoopinions), 
        "confirmationbias": clippingprobability(confirmationbias),
        "activity": clippingprobability(activity),
    }

# %%
for profile in users10:
    traits = traitsfrompersona(profile)
    print(
        profile["username"],
        profile["mbti"],
        traits
    )
# Out:
# millerhospitality ESTJ {'pronetoopinions': 0.45, 'confirmationbias': 0.7100000000000002, 'activity': 1.0}
# emma_logistics_guru ENFJ {'pronetoopinions': 0.68, 'confirmationbias': 0.6100000000000001, 'activity': 1.0}
# ryantechsavvy22 ENTJ {'pronetoopinions': 0.58, 'confirmationbias': 0.6100000000000001, 'activity': 1.0}
# biz_mind45 ESTJ {'pronetoopinions': 0.37, 'confirmationbias': 0.7100000000000002, 'activity': 1.0}
# JakeAgEcon ISTJ {'pronetoopinions': 0.45, 'confirmationbias': 0.7100000000000002, 'activity': 0.8799999999999999}
# EcoBizExplorer ISFJ {'pronetoopinions': 0.63, 'confirmationbias': 0.6600000000000001, 'activity': 0.96}
# intj_emily INTJ {'pronetoopinions': 0.5, 'confirmationbias': 0.6000000000000001, 'activity': 0.7999999999999999}
# sereneadvocate ISFJ {'pronetoopinions': 0.68, 'confirmationbias': 0.6100000000000001, 'activity': 0.96}
# hfarmer47 ISFJ {'pronetoopinions': 0.63, 'confirmationbias': 0.6600000000000001, 'activity': 0.8799999999999999}
# ethan_the_infp INFP {'pronetoopinions': 0.68, 'confirmationbias': 0.51, 'activity': 0.8799999999999999}

# %%
#based on the topics of interested the agents are being put toward one community side
def communityfromprofile(profile):
    return "discussion"

# %%
def firstopinion (profile):
    
    persona = profile["persona"].lower()
    bio = profile ["bio"].lower()
    topics = " ".join(profile["interested_topics"]).lower()
    profession = profile["profession"].lower() 

    text = persona + "" + bio + "" + topics + "" + profession

    #
    base = np.random.choice([-0.35,0.35])
    opinionshift = 0.0
    #based on the keywords found in the text it pushes into a direction of being analytical and sceptical - or leaning towards agreeableness 
    if any(word in text for word in [
        "analytical", "careful","methodical", "research"
    ]):
        opinionshift -= 0.08
    
    if any(word in text for word in [
        "creative", "ambitious", "innovative", "driven"
    ]):
        opinionshift += 0.08


    noise = np.random.uniform(-0.08,0.08) #bit of noise flavour
    return float (np.clip(base + opinionshift +noise, -1,1))

# %%
# Posting class that simulates the social media way of activity
#stance of post showcases the opion of the post it can be  -1 strongly against topic, 0 neutral or +1 in favour of topic
# community is in which community the post appears
#createdstep shows the time step for when the post was created

class RedditPost: 
    def __init__(self,postid, authorid, community, stanceofpost, createdstep,topics, treatment):
        self.postid = postid
        self.authorid = authorid
        self.community = community
        self.stanceofpost= stanceofpost
        self.createdstep = createdstep
        self.topics = topics
        self.treatment = treatment # added treatment for herd effect function
        self.upvotes = 0
        self.downvotes = 0 

        #added treatment/up-downvote 
        if treatment == 'up-treated':
            self.upvotes = 1
            self.downvotes = 0
        elif treatment == 'down-treated':
            self.upvotes = 0
            self.downvotes = 1
        else:
            self.upvotes = 0
            self.downvotes = 0

    @property
    def score(self):
        return self.upvotes - self.downvotes #popularity

# %%
# Model

class Reddit (mesa.Model):
    def __init__ (self, users, seed = 42):
        super().__init__ (seed = seed)

        self.currentstep = 0
        self.posts = []
        self.nextpostid = 1
        self.agentlist = []
        
        treatment_opt = ['up-treated', 'down-treated', 'control'] # added treatment options

        for profile in users: 
            traits = traitsfrompersona(profile)

            agent = Reddit_Useragent (
                model=self, 
                profile = profile, 
                firstopinion= firstopinion(profile),
                community = communityfromprofile(profile),
                pronetoopinions= traits ["pronetoopinions"],
                confirmationbias = traits["confirmationbias"],
                activity = traits["activity"]
            )

            self.agentlist.append(agent)


# the interests of the agents are taken into account
    def add_post(self, authorid,community,stanceofpost,topics, treatment):
        post = RedditPost (
            postid = self.nextpostid,
            authorid= authorid, 
            community= community,
            stanceofpost= stanceofpost, 
            createdstep= self.currentstep, 
            topics = topics,
            treatment = treatment, # added treatment
        )

        self.posts.append(post)
        self.nextpostid +=1


#recommender system that recommends posts based on the match to own interest
    def recommendpost (self, agent, feed_size = 5):
        ranked_posts=[]

        for post in self.posts: 
            opinion_similarity = 1 -abs(agent.opinion - post.stanceofpost)/2 #closeness to agent opinion
            score_effect =np.tanh(post.score / 5) #popularity
            age = self.currentstep - post.createdstep #newer post higher rank
            recency = 1/ (1+age)
            interest_effect = interest_similarity(agent, post)
            


            rank = (
                0.6 * score_effect
                +0.4 *opinion_similarity
                +0.5 * interest_effect
                +0.7 * recency
            )

            ranked_posts.append((rank, post))

        ranked_posts.sort(key=lambda x: x[0], reverse = True)
        return [post for rank, post in ranked_posts[:feed_size]]
    
    
    #acitivity of agents
    def step(self):
            self.currentstep += 1
            for agent in self.agentlist: 
                if random.random() < agent.activity: 
                    feed = self.recommendpost(agent,feed_size=5) #recommended posts

                    for post in feed: 
                        agent.react_to_post(post)

                    if random.random()< 0.3: #probability of 0.3 that agent will create a new post
                        new_post = agent.createpostfromopinion()
                        self.add_post(
                            authorid= agent.unique_id,
                            community=new_post["community"],
                            stanceofpost= new_post["stanceofpost"],
                            topics= new_post["topics"],
                            treatment=new_post['treatment'] # added treatment

                        )

# %%
model = Reddit (users10)
for agent in model.agentlist: 
    print(
        agent.username, 
        agent.mbti,
        agent.community, 
        round(agent.opinion, 2),
        round(agent.pronetoopinions,2),
        round(agent.confirmationbias,2),
        round(agent.activity,2),
    )
# Out:
# millerhospitality ESTJ discussion 0.29 0.45 0.71 1.0
# emma_logistics_guru ENFJ discussion -0.4 0.68 0.61 1.0
# ryantechsavvy22 ENTJ discussion 0.43 0.58 0.61 1.0
# biz_mind45 ESTJ discussion -0.33 0.37 0.71 1.0
# JakeAgEcon ISTJ discussion 0.43 0.45 0.71 0.88
# EcoBizExplorer ISFJ discussion 0.37 0.63 0.66 0.96
# intj_emily INTJ discussion -0.5 0.5 0.6 0.8
# sereneadvocate ISFJ discussion -0.33 0.68 0.61 0.96
# hfarmer47 ISFJ discussion -0.4 0.63 0.66 0.88
# ethan_the_infp INFP discussion -0.35 0.68 0.51 0.88

# %%
# recommender system that looks whether interests are similar

def interest_similarity (agent, post):
    agent_topics = set(agent.interested_topics)
    post_topics = set(post.topics)

    overlap = len(agent_topics.intersection(post_topics))
    total = len (agent_topics.union(post_topics))

    if total == 0:
        return 0.0
    
    return overlap/total

# %%
# running the simulation 

def run_simulation (model, n_steps = 30):
    opinionhistory = []
    scorehistory = []

    for step in range (n_steps +1):
        print("running step", step)
        opinionhistory.append(
            [agent.opinion for agent in model.agentlist]
        )

        scorehistory.append(
            [post.score for post in model.posts]
        )

        if step < n_steps:
            model.step()

    return np.array(opinionhistory), scorehistory

# %%
# adding treatment options
treatment_opt = ['up-treated', 'down-treated', 'control']
start_stances = [-0.5,0.0,0.5]
model = Reddit(users10)

for i in range(3):
    current_treat = treatment_opt[i % len(treatment_opt)] # account for different treatment options
    model.add_post(
        authorid = i+1, 
        community = "discussion",
        stanceofpost = start_stances[i] + np.random.uniform(-0.05,0.05),
        topics = ["Politics","Career","Risk"], 
        treatment = current_treat
    )

opinionhistory, scorehistory = run_simulation(model, n_steps=30)
# Out:
# running step 0
# running step 1
# running step 2
# running step 3
# running step 4
# running step 5
# running step 6
# running step 7
# running step 8
# running step 9
# running step 10
# running step 11
# running step 12
# running step 13
# running step 14
# running step 15
# running step 16
# running step 17
# running step 18
# running step 19
# running step 20
# running step 21
# running step 22
# running step 23
# running step 24
# running step 25
# running step 26
# running step 27
# running step 28
# running step 29
# running step 30

# %% [markdown]
# ### Polarization Phenomena
# Yang et al.(2024) argue that studying the opinion of users
# and how their opinions evolve during information propagation is crucial. For this they focused on Group Polarization Phenomena
#
# "Group Polarization occurs when individuals with similar views adopt more extreme positions after exchanging opinions.For example, a group with moderately conservative views may become more conservative through
# interaction."(Yang et al.,2024).
#
# To reproduce this phenomena simplified on a small scale we update the intial opinion by reinforcing these. At first agents have different starting opinions. This is common in real life and can cause the possibility of conflict. Then during interactions the agents create stronger stance in their opinion especially when exposed to agreeing posts. Thereby they move further away from the opposing post. Because this process is reapeated over stepts the opinion move further and further away from the opposing showing the polarization.

# %%
#Plotting Figure 4

plt.figure (figsize= (12,5))

for i in range (opinionhistory.shape[1]):
    plt.plot(opinionhistory[:,i],label =f"Agent {i+1}")

plt.axhline(0,color= "blue", linestyle= "--")
plt.title("Figure 4: Opinion over time")
plt.xlabel ("Timestep")
plt.ylabel("Opinion")
plt.legend(ncol = 2, fontsize = 8)
plt.show()

# %% [markdown]
# Figure 4 shows that the agents move into different directions gradually. Moving either more to the negative or positive side. This shows how the interaction leads the agents to adapt more polarized opinions.

# %%
polarizationstrength = np.std(opinionhistory, axis= 1)

plt.figure(figsize=(8,4))
plt.plot(polarizationstrength, marker = "o")
plt.title("Opinion dispersion over time")
plt.xlabel("Timestep")
plt.ylabel("Standard deviation of opinions")
plt.show()

# %% [markdown]
# The plot shows how the standard deviation rises over time step and remains quite high. The opinions become more spread out over time showcasing the polarization and divergence of agents.
#
# Note: own addition plot

# %%
def comparetoround0 (opinionhistory, tolerance= 0.02):
    baseline = opinionhistory[0]
    results = []

    for t in range (opinionhistory.shape[0]):
        current = opinionhistory[t]

        more_progressive = np.sum(current > baseline +tolerance)
        more_conservative = np.sum(current < baseline - tolerance)
        draw = np.sum(np.abs(current-baseline) <= tolerance)

        results.append({
            "timestep" : t, 
            "more_conservative": more_conservative,
            "more_progressive": more_progressive,
            "draw": draw
        })

    return pd.DataFrame(results)

# %%
figure5_df = comparetoround0(opinionhistory)
figure5_df

print (figure5_df.columns)
# Out:
# Index(['timestep', 'more_conservative', 'more_progressive', 'draw'], dtype='object')

# %%
selectedtimesteps = [0,5,10,15,20,25,30]
plotdf = figure5_df[figure5_df["timestep"].isin(selectedtimesteps)]


plt.figure(figsize=(10,5))

ylabels= [f"Timestep{t}" for t in plotdf["timestep"]]

plt.barh(
    ylabels, 
    plotdf["more_conservative"],
    color = "blue", 
    label= "more_conservative"
)

plt.barh(
    ylabels, 
    plotdf["more_progressive"],
    left=plotdf["more_conservative"],
    color = "green", 
    label= "more_progressive"
)

plt.barh(
    ylabels, 
    plotdf["draw"],
    left=plotdf["more_conservative"]+ plotdf["more_progressive"],
    color = "yellow", 
    label= "no clear change"
)

plt.xlabel("Number of opinions")
plt.title ("Polarization relative to round 0 ")
plt.legend(loc= "lower right")
plt.tight_layout()
plt.show()

# %% [markdown]
# Figure 5 shows the changes of opinion in comparison to the stance of round 0. The agents tend to behave in different manners, either they adapt to a more conservative opinion (negative values) or they become more progressive (positive values). This aligns with the paper stating that repeated interaction shifting their intial opinion and amplfiying the opinion tendencies creating group polarization.
#
# While the model is a simplified version it shows how the simulation of social interaction can show real life phenomenas.

# %% [markdown]
# ### Herd effect
#
# The herd effect on reddit describes how users adopt the views and actions of the majority rather than formulating one's own opinion. The paper argues that there's a tendency to align with popular opinion, therefore posts with many likes are likey to receive additional likes. We want to try and replicate these findings by simulating the actions of 10 agents.
#
# The paper found that having more agents is imparative for accurately simulating group behavior, as the individual perspectives will be more diverse. Nevertheless, we followed the papers approach and simulated how the agents interact with posts pertaining to different topics for 40 time steps.
# We randomly choose which treatment gets applied to the initial post and observe how the agents react to this by either upvoting or downvoting it. We then sum up the scores (upvotes-downvotes) each post receives and plot the results in a graph to compare the average scores across the different treatment groups. Furthermore, we want to see if there is a noticeable difference between the various discussion topics as was found in the paper 'Social Influence Bias: A Randmized Experiment' by Muchnik, Sinan and Sean (https://www.researchgate.net/publication/255716248_Social_Influence_Bias_A_Randomized_Experiment).

# %%
# herd effect function to collect data for graph

def herd_effect_experiment(model, n_steps=40): # 40 steps just like in the paper
    for i in range(n_steps):
        model.step()

    exp_results = []
        
    for post in model.posts:
        top_topic = post.topics[0] if isinstance(post.topics, list) else post.topics
            
        exp_results.append({
            'Treatment': post.treatment,
            'Score': post.score,
            'Topic': top_topic
        })
    df = pd.DataFrame(exp_results)
    return df

# %%
herd_df = herd_effect_experiment(model)

print(herd_df)
# Out:
#         Treatment  Score              Topic
# 0      up-treated     20           Politics
# 1    down-treated     -3           Politics
# 2         control      1           Politics
# 3      up-treated     24          Economics
# 4    down-treated     70          Economics
# ..            ...    ...                ...
# 196    up-treated      1          Economics
# 197    up-treated      2  Culture & Society
# 198  down-treated     -1  Culture & Society
# 199    up-treated      2          Economics
# 200    up-treated      1          Economics
#
# [201 rows x 3 columns]

# %%
# herd effect visualization. figure 6 of paper

def herd_effect_viz(data):
    
    g = sns.FacetGrid(data, col='Topic', col_wrap=4, height=4, aspect=1.2, sharey=True)

    g.map_dataframe(sns.pointplot, x='Treatment', y='Score', hue='Treatment', order=['down-treated', 'control', 'up-treated'], hue_order=['down-treated', 'control', 'up-treated'], linestyles= 'solid', capsize=0.1, markers=['o', 's', 'D'])

    g.set_axis_labels('Treatment', 'Mean Score')
    #plt.subplots_adjust(hspace=0.6, wspace=0.4)
    plt.tight_layout()
    plt.show()

# %%
herd_effect_viz(herd_df)

# %% [markdown]
# This graph replicates figure 6 of the paper and shows the mean score of comments which were either initially liked as up-treated, initially disliked as down-treated and control group comments (neither liked nor disliked). Since this is a simulation, the results can vary, however, we can generally observe, that down-treated posts consistently rack in lower mean scores than the other two treatments, contorl and up treatment, with up-treatmed posts generally having the highest average post scores, but the error bars are pretty long so there's some level of uncertainty here. Interestingly, the down-treated posts generally also see very little to no variance in the mean, while control and up-treated posts see a greater span. Running the experiment with more than 10 agents, like the paper did, would lead to more significant and reliable results to better differentiate between the three treatment groups.
#
# We can also oberve here that there's a difference between discussion topics, however, we will be highlighting this in the next graph.

# %%
# additional visulaization of the herd effect

def herd_effect_viz_2(data):
    sns.barplot(data, x='Treatment', y='Score', hue='Topic')
    plt.title('Average Score by Topic and Treatment ')
    plt.xlabel('Treatment')
    plt.ylabel('Mean Score')
    plt.show()

# %%
herd_effect_viz_2(herd_df)

# %% [markdown]
# Similarily to our previous graph (plotting the herd effect like in figure 6 of the paper), this graph shows the average post score of each treatment group but as a barplot, showing the difference in topic side-by-side. Again, while each run of the simulation yields slightly different results, we can generally see quite a difference in scores each topic receives for each treatment group which is also what was found in the paper written by Muchnik, Sinan and Sean. So it appears that the topic being discussed has quite an impact on whether agents behave in a herding manner.
